# %%
# Environment & Config Check — Revenue vs Risk

# %%
# allow importing from src/ when running inside notebooks/
import sys, pathlib
PROJECT_ROOT = pathlib.Path.cwd().parent  # because this notebook is in notebooks/
SRC_DIR = PROJECT_ROOT / "src"
if str(SRC_DIR) not in sys.path:
    sys.path.insert(0, str(SRC_DIR))

from src.config import load_env, get_key, data_dir
import numpy as np, pandas as pd

# load env and print key paths
load_env()
print("API_KEY_DUMMY present:", get_key("API_KEY_DUMMY") is not None)
print("DATA_DIR:", data_dir())
print("DATA_DIR_RAW:", data_dir("raw"))
print("DATA_DIR_PROCESSED:", data_dir("processed"))

# quick NumPy test
a = np.array([1,2,3]); b = np.array([4,5,6])
print("Vectorized dot:", a @ b)  # expect 32

# quick pandas test
df = pd.DataFrame({"x":[1,2], "y":[3,4]})
df.info()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 8
#       5 if str(SRC_DIR) not in sys.path:
#       6     sys.path.insert(0, str(SRC_DIR))
# ----> 8 from src.config import load_env, get_key, data_dir
#       9 import numpy as np, pandas as pd
#      11 # load env and print key paths
#
# ModuleNotFoundError: No module named 'src'

# %%
# Make sure the PROJECT ROOT (not src/) is on sys.path
import sys, pathlib
CWD = pathlib.Path.cwd()
PROJECT_ROOT = CWD.parent if CWD.name == "notebooks" else CWD
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))
print("Using PROJECT_ROOT:", PROJECT_ROOT)

from src.config import load_env, get_key, data_dir
import numpy as np, pandas as pd

# load env and print key paths
load_env()
print("API_KEY_DUMMY present:", get_key("API_KEY_DUMMY") is not None)
print("DATA_DIR:", data_dir())
print("DATA_DIR_RAW:", data_dir("raw"))
print("DATA_DIR_PROCESSED:", data_dir("processed"))

# quick NumPy test
a = np.array([1,2,3]); b = np.array([4,5,6])
print("Vectorized dot:", a @ b)  # expect 32

# quick pandas test
df = pd.DataFrame({"x":[1,2], "y":[3,4]})
df.info()
# Out:
# Using PROJECT_ROOT: C:\Users\User\bootcamp_Khushi_Khanna\project\revenue_risk_model
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 9
#       6     sys.path.insert(0, str(PROJECT_ROOT))
#       7 print("Using PROJECT_ROOT:", PROJECT_ROOT)
# ----> 9 from src.config import load_env, get_key, data_dir
#      10 import numpy as np, pandas as pd
#      12 # load env and print key paths
#
# File ~\bootcamp_Khushi_Khanna\project\revenue_risk_model\src\config.py:2
#       1 import os
# ----> 2 from dotenv import load_dotenv, find_dotenv
#       4 def load_env(dotenv_path: str | None = None) -> None:
#       5     path = dotenv_path or find_dotenv(usecwd=True)
#
# ModuleNotFoundError: No module named 'dotenv'

# %%
import sys, pathlib, os

NB_DIR = pathlib.Path.cwd().resolve()
print("NB_DIR:", NB_DIR)

# Try to auto-detect project root by looking for src/config.py up the tree
candidates = [NB_DIR] + list(NB_DIR.parents)
PROJECT_ROOT = next((p for p in candidates if (p / "src" / "config.py").exists()), None)
print("DETECTED PROJECT_ROOT:", PROJECT_ROOT)

if PROJECT_ROOT is None:
    raise FileNotFoundError("Couldn't find src/config.py above this notebook. "
                            "Make sure you're inside revenue_risk_model/notebooks/ and that src/config.py exists.")

# put project root (not src) on sys.path
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))
print("sys.path[0]:", sys.path[0])
# Out:
# NB_DIR: C:\Users\User\bootcamp_Khushi_Khanna\project\revenue_risk_model\notebooks
# DETECTED PROJECT_ROOT: C:\Users\User\bootcamp_Khushi_Khanna\project\revenue_risk_model
# sys.path[0]: C:\Users\User\bootcamp_Khushi_Khanna\project\revenue_risk_model

# %%
from src.config import load_env, get_key, data_dir
import numpy as np, pandas as pd

load_env()
print("API_KEY_DUMMY present:", get_key("API_KEY_DUMMY") is not None)
print("DATA_DIR:", data_dir())
print("DATA_DIR_RAW:", data_dir("raw"))
print("DATA_DIR_PROCESSED:", data_dir("processed"))

a = np.array([1,2,3]); b = np.array([4,5,6])
print("Vectorized dot:", a @ b)

pd.DataFrame({"x":[1,2], "y":[3,4]}).info()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from src.config import load_env, get_key, data_dir
#       2 import numpy as np, pandas as pd
#       4 load_env()
#
# ModuleNotFoundError: No module named 'src'

# %%
import sys, subprocess
print("Using interpreter:", sys.executable)
subprocess.check_call([sys.executable, "-m", "pip", "install", "python-dotenv"])
# Out:
# Using interpreter: C:\Users\User\env\Scripts\python.exe
# 0

# %%
# --- Auto-detect project root and import src.config ---
import sys, pathlib
import sys, subprocess
print("Using interpreter:", sys.executable)

# install the core packages into THIS interpreter
subprocess.check_call([sys.executable, "-m", "pip", "install", "numpy", "pandas", "matplotlib", "scikit-learn", "yfinance", "beautifulsoup4", "requests", "pyarrow", "python-dotenv"])


NB_DIR = pathlib.Path.cwd().resolve()
print("NB_DIR:", NB_DIR)

# Walk up until we find a folder that contains src/config.py
PROJECT_ROOT = None
for p in [NB_DIR, *NB_DIR.parents]:
    if (p / "src" / "config.py").exists():
        PROJECT_ROOT = p
        break

print("DETECTED PROJECT_ROOT:", PROJECT_ROOT)
if PROJECT_ROOT is None:
    raise FileNotFoundError(
        "Couldn't find src/config.py above this notebook.\n"
        "Make sure your structure is .../revenue_risk_model/src/config.py "
        "and this notebook lives in .../revenue_risk_model/notebooks/."
    )

# Put the PROJECT ROOT (not src/) on sys.path
sys.path.insert(0, str(PROJECT_ROOT))
print("sys.path[0]:", sys.path[0])

from src.config import load_env, get_key, data_dir
import numpy as np, pandas as pd

# --- sanity checks ---
load_env()
print("API_KEY_DUMMY present:", get_key("API_KEY_DUMMY") is not None)
print("DATA_DIR:", data_dir())
print("DATA_DIR_RAW:", data_dir("raw"))
print("DATA_DIR_PROCESSED:", data_dir("processed"))

a = np.array([1,2,3]); b = np.array([4,5,6])
print("Vectorized dot:", a @ b)
pd.DataFrame({"x":[1,2], "y":[3,4]}).info()
# Out:
# Using interpreter: C:\Users\User\env\Scripts\python.exe
# NB_DIR: C:\Users\User\bootcamp_Khushi_Khanna\project\revenue_risk_model\notebooks
# DETECTED PROJECT_ROOT: C:\Users\User\bootcamp_Khushi_Khanna\project\revenue_risk_model
# sys.path[0]: C:\Users\User\bootcamp_Khushi_Khanna\project\revenue_risk_model
# API_KEY_DUMMY present: False
# DATA_DIR: ./data
# DATA_DIR_RAW: ./data/raw
# DATA_DIR_PROCESSED: ./data/processed
# Vectorized dot: 32
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2 entries, 0 to 1
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   x       2 non-null      int64
#  1   y       2 non-null      int64
# dtypes: int64(2)
# memory usage: 164.0 bytes

# %%
# Environment & Config Check — Revenue vs Risk

# %%
# --- Setup for environment & config check ---

# ensure we can import from src/
import sys, pathlib

NB_DIR = pathlib.Path.cwd().resolve()
print("Notebook is running in:", NB_DIR)

# walk up until we find src/config.py
PROJECT_ROOT = None
for p in [NB_DIR, *NB_DIR.parents]:
    if (p / "src" / "config.py").exists():
        PROJECT_ROOT = p
        break

if PROJECT_ROOT is None:
    raise FileNotFoundError("Couldn't find src/config.py — check your folder structure!")

# put project root (not src/) on sys.path
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))
print("Using PROJECT_ROOT:", PROJECT_ROOT)

# imports
from src.config import load_env, get_key, data_dir
import numpy as np, pandas as pd

# load env and check keys
load_env()
print("API_KEY_DUMMY present:", get_key("API_KEY_DUMMY") is not None)
print("DATA_DIR:", data_dir())
print("DATA_DIR_RAW:", data_dir("raw"))
print("DATA_DIR_PROCESSED:", data_dir("processed"))

# quick NumPy test
a = np.array([1,2,3]); b = np.array([4,5,6])
print("Vectorized dot:", a @ b)  # should be 32

# quick pandas test
pd.DataFrame({"x":[1,2], "y":[3,4]}).info()
# Out:
# Notebook is running in: C:\Users\User\bootcamp_Khushi_Khanna\project\revenue_risk_model\notebooks
# Using PROJECT_ROOT: C:\Users\User\bootcamp_Khushi_Khanna\project\revenue_risk_model
# API_KEY_DUMMY present: True
# DATA_DIR: ./data
# DATA_DIR_RAW: ./data/raw
# DATA_DIR_PROCESSED: ./data/processed
# Vectorized dot: 32
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2 entries, 0 to 1
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   x       2 non-null      int64
#  1   y       2 non-null      int64
# dtypes: int64(2)
# memory usage: 164.0 bytes
